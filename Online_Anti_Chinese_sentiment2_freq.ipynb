# %%
import pandas as pd

# %%
# https://github.com/egbertbouman/youtube-comment-downloader
# !pip install https://github.com/egbertbouman/youtube-comment-downloader/archive/master.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      | 10 kB 8.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 290 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 749 kB 62.0 MB/s
# ...
#   Created wheel for youtube-comment-downloader: filename=youtube_comment_downloader-0.1-py3-none-any.whl size=7554 sha256=ba0ef27b3fc8fae0f7740bfd9161d15701613c645584a5072360c1c486ba0753
#   Stored in directory: /tmp/pip-ephem-wheel-cache-372daqs9/wheels/92/2e/30/15612727e4b833374713aa62770f8a07d8c89d598a1bebbbea
# Successfully built youtube-comment-downloader
# ...
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.6.2
#     Uninstalling regex-2022.6.2:
#       Successfully uninstalled regex-2022.6.2
# ...

# %%
# !pip install https://github.com/egbertbouman/youtube-comment-downloader/archive/master.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://github.com/egbertbouman/youtube-comment-downloader/archive/master.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...

# %%
# 형태소 분석기 https://konlpy.org/ko/latest/index.html
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 6.3 MB/s
# ...
#      |████████████████████████████████| 453 kB 58.7 MB/s
# ...

# %%
#형태소 분석기 준비
from konlpy.tag import *

hannanum = Hannanum()
kma = Kkma()
komoran = Komoran()
okt = Okt()

# %%
# 형태소 분석기를 사용하여 특정 품사의 형태소만 수집
# 형태소 분석기별 태그 목록 https://docs.google.com/spreadsheets/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0

from konlpy.tag import Kkma

kma = Kkma()

test_sent = u"오늘 수업도 재밌으신가요? 아니면 너무 어려우신가요?"  # Unicode로 처리하라는 의미로 u를 붙여 주었습니다.

#꼬꼬마 코드 예제
print('- 꼬꼬마 출력 결과: ')
print("형태소 분할:\t", kma.morphs(test_sent))     # '\t'는 탭입니다. 
print("명사 추출:\t", kma.nouns(test_sent))
print("POS 태깅:\t", kma.pos(test_sent))
print("POS 태깅(flatten):\t", kma.pos(test_sent, flatten=False, join=False))  # 세종 스타일!
print("POS 태깅(join):\t", kma.pos(test_sent, join=True))
print("문장 분할:\t", kma.sentences(test_sent))
# Out:
# - 꼬꼬마 출력 결과:
# 형태소 분할:	 ['오늘', '수업', '도', '재밌', '으시', 'ㄴ가요', '?', '아니', '면', '너무', '어렵', '시', 'ㄴ가요', '?']
# 명사 추출:	 ['오늘', '수업']
# POS 태깅:	 [('오늘', 'NNG'), ('수업', 'NNG'), ('도', 'JX'), ('재밌', 'VA'), ('으시', 'EPH'), ('ㄴ가요', 'EFQ'), ('?', 'SF'), ('아니', 'VCN'), ('면', 'ECE'), ('너무', 'MAG'), ('어렵', 'VV'), ('시', 'EPH'), ('ㄴ가요', 'EFQ'), ('?', 'SF')]
# POS 태깅(flatten):	 [[('오늘', 'NNG')], [('수업', 'NNG'), ('도', 'JX')], [('재밌', 'VA'), ('으시', 'EPH'), ('ㄴ가요', 'EFQ'), ('?', 'SF')], [('아니', 'VCN'), ('면', 'ECE')], [('너무', 'MAG')], [('어렵', 'VV'), ('시', 'EPH'), ('ㄴ가요', 'EFQ'), ('?', 'SF')]]
# POS 태깅(join):	 ['오늘/NNG', '수업/NNG', '도/JX', '재밌/VA', '으시/EPH', 'ㄴ가요/EFQ', '?/SF', '아니/VCN', '면/ECE', '너무/MAG', '어렵/VV', '시/EPH', 'ㄴ가요/EFQ', '?/SF']
# 문장 분할:	 ['오늘 수업도 재밌으신가요?', '아니면 너무 어려우신가요?']

# %%
from konlpy.tag import Komoran   # KOMORAN  @Shineware


# Initiating
kom = Komoran()

test_sent = u"오늘 수업도 재밌으신가요? 아니면 너무 어려우신가요?"  # Unicode로 처리하라는 의미로 u를 붙여 주었습니다.


#코모란 코드 예제
print('- 코모란 출력 결과:') #코모란 코드 예제
print("형태소 분절:\t\t", kom.morphs(test_sent))
print("명사 추출:\t\t", kom.nouns(test_sent))
print("POS 태깅:\t\t", kom.pos(test_sent))
print("POS 태깅(joined):\t", kom.pos(test_sent, flatten=False, join=True))
# Out:
# - 코모란 출력 결과:
# 형태소 분절:		 ['오늘', '수업', '도', '재밌', '으시', 'ㄴ가요', '?', '아니', '면', '너무', '어렵', '시', 'ㄴ가요', '?']
# 명사 추출:		 ['오늘', '수업']
# POS 태깅:		 [('오늘', 'NNG'), ('수업', 'NNG'), ('도', 'JX'), ('재밌', 'VA'), ('으시', 'EP'), ('ㄴ가요', 'EF'), ('?', 'SF'), ('아니', 'VCN'), ('면', 'EC'), ('너무', 'MAG'), ('어렵', 'VA'), ('시', 'EP'), ('ㄴ가요', 'EF'), ('?', 'SF')]
# POS 태깅(joined):	 [['오늘/NNG', '수업/NNG', '도/JX', '재밌/VA', '으시/EP', 'ㄴ가요/EF', '?/SF', '아니/VCN', '면/EC', '너무/MAG', '어렵/VA', '시/EP', 'ㄴ가요/EF', '?/SF']]

# %%
# 파일을 불러와서 형태소 분석을 해보겠습니다.

with open("/content/1-1.2022 Beijing Winter Olympics opening ceremony_YouTube Comments.txt", "r") as f:
    text = f.read()

# %%
text
# Out:
# '1\t우리나라는 동네 북인가 저쪽에선 독도달라하고 이쪽에선 우리 문화달라하고\n2\t따라할걸 따라헤야지 애휴 중국 진짜 한국이 얼많아 부러우면 애휴 \n3\t조선족 놈들은 한국문화를 도용말라. 중국국적이여서 중국 문화나 배우지 왜 한국에 피해를 주냐. 한국에 와서 세금 충내고 범죄나 저질르는 범좌자들.\n4\t개인방송에서 조선족 여자가 그럼 조선족은 무슨 옷 입어야하냐고 어이없어 하며 되묻던데 평소에 한복입나\n5\t56개 소수민족에 조선족이 잇으니 한복 나오는게 당연하죠\n6\t흠 중국이진짜믜쳐다는거라고생각하고 저는중국한테이르케말할게요 야이중국같은 \n7\t아니 왜 저기서 아무말도 못하고 있는건데. 억울하네\n8\t이 사람들의 역사는 그들이 전쟁과 기근을 피하기 위해 중국 동북부로 피신했지만 지금은 남한의 공격을 받았다는 것입니다.  앞으로 한반도에서 온 사람들이 동해로 피난을 가야 할 것 같다.\n9\t저것만 봐도 우리문화 얼마나 탐내고 다니는건지\n10\t원래는 중국도 따로  문화옷이 있었으나 중국이 그걸 불태워서 결국 그 전통의상은 잊혀졌고 2000년대에 나온게 중국\'한푸\'라 생각합니다 결론은 지네나라 전통의상 버리고 새 전통의상 얻은셈\n11\t분명 김치 소리는 하지도 않았는데  왜 말씀이 다왔는지 모르네요. \n12\t한국인들이 다민족국가의 개념에 익숙하지 않기 때문이고, 두 번째로 중국은 이미 김치를 파오차이의 일종이라 하거나 한복은 명나라 한푸를 베낀 것이라고 하는 등 한국인들의 경계심과 적의를 크게 키워왔기 때문임\n13\t와. 김치싸대기 날리고 싶네. \n14\t중국 화폐에도 한복입은여자가 있어서 처음보고 놀랐음\n15\t나도앞으로 치파오가 중국교민이 소수민족이라 우리나라옷이기도 하다는 얘기하고 다녀야겟다\n16\t아무리 하나의민족이라고한들. 옆에버젖이 한국이 있는데. 그걸왜 그자리에 내보내지 미친 나라인가\n17\t중국에서 하는거만 빼면 다 좋은데\n18\t지들 손으로 문화 부수고 남의 문화 탐내는 꼴이 엄마뒤진 나라 답네요\n19
# ...

# %%
from konlpy.tag import Kkma
from collections import Counter 

#명사만 추출
tags = ['NNG','NNP'] #현재 일반명사(nng), 고유명사(nnp), 동사(vv), 형용사(va) 등을 넣을 수 있음.

NN = []
for ej in kma.pos(text): #형태소 분석기 선택
    if ej[1] in tags:
        NN.append(ej[0])


print(NN)

count = Counter(NN)
print(count)
print(count.most_common(10))
# Out:
# ['나라', '동네', '북', '저쪽', '독도', '이쪽', '문화', '애', '중국', '한국', '애', '조선', '족', '놈', '한국', '문화', '도용', '중국', '국적', '여', '중국', '문화', '한국', '피해', '한국', '세금', '충', '내고', '범죄', '범', '좌', '자', '방송', '조선족', '여자', '조선족', '옷', '평소', '한복', '입', '소수', '민족', '조선족', '한복', '흠', '중국', '진짜', '생각', '중국', '중국', '말', '사람', '역사', '전쟁', '기근', '중국', '동북부', '피신', '지금', '남한', '공격', '앞', '한반도', '사람', '동해', '피난', '문화', '원래', '중국', '문화', '옷', '중국', '결국', '전통', '상은', '중국', '라', '생각', '결론', '지네', '나라', '전통', '상', '전통', '상', '김치', '소리', '하지', '말씀', '한국인', '다민족', '국가', '개념', '중국', '김치', '파오', '차이', '일종', '한복', '명나라', '한국인', '경계심', '적의', '임', '김치', '대기', '중국', '화폐', '한복', '여자', '처음', '나도', '앞', '치', '파오', '중국', '교민', '소수', '민족', '우리나라', '옷', '기도', '하다', '얘기', '하나', '민족', '한국', '자리', '나라', '중국', '지', '손', '문화', '수고', '남의', '문화', '꼴', '엄마', '나라', '문', '눈', '우리나라', '꺼', '어이', '중국', '꽃', '하면', '중국', '중화', '중화', '역사', '민족', '미래', '겸손', '중국', '안달', '한국', '전통', '한복', '올림픽', '중국', '재', '정신', '한국', '요즘', '김치', '지', '우리나라', '한복'
# ...
